# %% [markdown]
# # Introduzione a *matplotlib*<br>
# > Antonio Piemnontese 2025

# %% [markdown]
# Vedi [questo video di riassunto](https://www.tiktok.com/@lunar_831/photo/7509076528349678856?is_from_webapp=1&sender_device=pc) dei 10 principali plot con `matplotlib` (e `seaborn`).

# %%
# importiamo la libreria Matplotlib (quella di base per la grafica; ce ne sono molte altre: seaborn, ecc)

# %%
import matplotlib as mlp           # il package completo

import matplotlib.pyplot as plt    # la parte del package per fare plotting in python

# %matplotlib inline # evita di digitare per ogni plot la funzione'plt.show()'

# %%
# se utilizziamo la shell di Python dobbiamo specificare anche il comando che segue per visualizzare i dati.
# in Jupyter non è necessario.

# %%
# possiamo rappresentare una lista direttamente in questo modo

# %% [markdown]
# Iniziamo a vedere alcuni semplici plot, disponibili anche in pandas:

# %%
plt.plot([5,7,2,4]) # in ordinata
                    # una funzione (non un metodo)

# %%
plt.plot([5,7,2,4], [4,6,9,2], 'ro') # due liste (per ascisse ed ordinate); 'ro' specifica il puntino (circle marker)
                                     # di colore red

# %%
plt.plot([5,7,2,4], [4,6,9,2], 'bo') # due liste (per ascisse ed ordinate); 'ro' specifica il puntino (circle marker) 
                                     # di colore blue

# %%
plt.plot([5,7,2,4], [4,6,9,2], 'r^') # possibilità come marker:
                                     # '.'          point marker
                                     # ','          pixel marker
                                     # 'o'          circle marker
                                     # '*'          star marker
                                     # '^'          triangle up marker
                                     # ecc (vedi help con shift+tab)

# %%
plt.plot([5,7,2,4], [4,6,9,2], 'b.') # possibilità come colore:
                                     # 'b'          blue
                                     # 'g'          green
                                     # 'r'          red
                                     # 'c'          cyan
                                     # 'm'          magenta
                                     # 'y'          yellow
                                     # 'k'          black
                                     # 'w'          white

                                     # '.' fornisce uno scatterplot

# %%
# creiamo due oggetti (utili dopo)
# sono i DATI:
x = [50, 70, 90, 65]
y = [129, 192, 163, 172]

# %% [markdown]
# Attenzione: i dati sono i dati (qui x e y). In un plot a linea, i dati sono UNITI da una linea, ma è solo un artificio grafico.

# %%
plt.plot(x, y, linewidth = 4.0) # linewidth specifica lo spessore della linea

# %%
help(plt.plot) # alternativa per l'help
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(
#     *args: 'float | ArrayLike | str',
#     scalex: 'bool' = True,
#     scaley: 'bool' = True,
#     data=None,
#     **kwargs
# ) -> 'list[Line2D]'
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
# ...

# %%
plt.plot(x, y, linewidth = 2.0, linestyle = '--') # linestyle specifica lo stile della linea
                                                  # '-'          solid line style
                                                  # '--'         dashed line style
                                                  # '-.'         dash-dot line style
                                                  # ':'          dotted line style
                                                  # ecc (vedi help con shift+tab)

# %%
plt.plot(x, y, linewidth = 1.0, ls = '-', marker = "o", markersize = 3) # marker come argomento a sè

# %%
plt.plot(x, y, linewidth = 1.0, linestyle = '-', marker = "o", markersize = 10, markerfacecolor = 'red') 
                                                 # puntini vuoti (bianchi dentro) di dimensione 10

# %%
plt.plot(x, y, lw = 1.0, ls = '-', marker = "o", ms = 10, mfc = 'white') # con alcuni argomenti (parole multiple?) abbreviati

# %% [markdown]
# Sinora abbiamo visto **singole funzioni** di plotting fornite da 'matplotlib'.<br>
# Entriamo ora nel cuore di 'matplotlib', che infatti permette di **costruire il plot poco per volta** - non possibile con pandas che semplicemente fornisce dei metodi di plotting per le classi 'dataframe' e 'serie', con i relativi argomenti tra ().<br>

# %%
plt.plot() # il grafico vuoto (solo le coordinate) - SENZA DATI (i valori dei tick degli assi?)
# Out:
# []

# %%
# specifichiamo il titolo del grafico e il nome degli assi

# %%
plt.plot(x, y)           # il grafico con i dati (e i tick corrispondenti)

# %%
plt.plot(x, y)           # il grafico vuoto (solo le coordinate)
plt.title("TITLE")
plt.xlabel("Asse X")
plt.ylabel("Asse Y")
# Out:
# Text(0, 0.5, 'Asse Y')

# %%
# come la cella prima, con i colori in più:
plt.plot(x, y, color = "red")
plt.title("TITLE", color = "blue")
plt.xlabel("Asse X", color = "purple")
plt.ylabel("Asse Y", color = "green")
# Out:
# Text(0, 0.5, 'Asse Y')

# %%
plt.plot(x, y)
plt.title("TITLE", color = "blue")
plt.xlabel("Asse X", color = "purple")
plt.ylabel("Asse Y", color = "green")
plt.grid(True)            # griglia
plt.legend(['Legend1'])   # legenda (loc = 1 def, angolo top-right)

# %%
plt.plot(x, y)
plt.title("TITLE", color = "blue")
plt.xlabel("Asse X", color = "purple")
plt.ylabel("Asse Y", color = "green")
plt.grid(True)
plt.legend(['Legend1'], loc = 2) # legenda in posizione differente (angolo top-left)

# %% [markdown]
# Possibili posizioni della legenda:
# * 0
# * 1 in alto a destra
# * 2 in alto a sinistra
# * 3 in basso a destra
# * 4 in basso a sinistra
# * 5 a destra
# * 6 centrato a sinistra
# * 7 centrato a destra
# * 8 centrato basso
# * 9 centrato alto
# * 10 al centro

# %% [markdown]
# Codici dei colori:
#
# * b blu
# * c ciano
# * g verde
# * m magenta
# * r rosso
# * y giallo
# * k nero
# * w bianco

# %%
# 3 plot sovrapposti
plt.plot([1,2,3,4],[1,4,8,15],'b*')
plt.plot([1,3,5,7],[1,4,8,12],'g^')
plt.plot([1,2,3,5],[2,5,4,12],'ro')
plt.legend(['First','Second','Third'],loc=0)  # 3 legende, una per serie

# %%
# creiamo più sottografici (equivalente di 'par=mfrow' di R).
# i numeri tra parentesi indicano numero di righe e di colonne del layout e numero del sottografico

# %%
# plt.subplot (n1,n2,n3) dove n1 e n2 sono le posizioni della matrice dei plot ed n3 è la posizione sulla quale lavorare:

plt.subplot(2,2,1) # sottografico 1 del layout 2x2
plt.plot([1,2,3,4],[1,4,8,15],'b*')

plt.subplot(2,2,2) # sottografico 2 del layout 2x2
plt.plot([1,3,5,7],[1,4,8,12],'g^')

plt.subplot(2,2,3) # sottografico 3 del layout 2x2
plt.plot([1,2,3,5],[2,5,4,12],'ro')

plt.subplot(2,2,4) # sottografico 4 del layout 2x2
plt.plot([1,2,3,5],[2,5,4,12],'b')

# %%
plt.subplot(1,2,1)
plt.plot([1,2,3,4],[1,4,8,15],'b*')

plt.subplot(1,2,2)
plt.plot([1,3,5,7],[1,4,8,12],'g^')

# %%
# piechart

# %%
plt.pie(x)  # colori di default
# Out:
# ([<matplotlib.patches.Wedge at 0x19c6a32c1a0>,
# ...
#  [Text(0.9253788637715525, 0.5947049339671486, ''),
#   Text(-0.3990885090653131, 1.0250504192145993, ''),
#   Text(-0.8899184718302892, -0.6465640830538323, ''),
#   Text(0.8104152212520455, -0.7437924234374792, '')])

# %%
col1 = ["yellow", "red", "purple", "orange"]

# %%
plt.pie(x, colors = col1) # specifica dei colori
# Out:
# ([<matplotlib.patches.Wedge at 0x19c6b760cd0>,
# ...
#  [Text(0.9253788637715525, 0.5947049339671486, ''),
#   Text(-0.3990885090653131, 1.0250504192145993, ''),
#   Text(-0.8899184718302892, -0.6465640830538323, ''),
#   Text(0.8104152212520455, -0.7437924234374792, '')])

# %%
lab1 = ['A','B','C','D']
plt.pie(x, colors = col1, labels = lab1) # specifica delle label
# Out:
# ([<matplotlib.patches.Wedge at 0x19c6b7a8b90>,
# ...
#  [Text(0.9253788637715525, 0.5947049339671486, 'A'),
#   Text(-0.3990885090653131, 1.0250504192145993, 'B'),
#   Text(-0.8899184718302892, -0.6465640830538323, 'C'),
#   Text(0.8104152212520455, -0.7437924234374792, 'D')])

# %%
ex1 = [0.5,0,0,0] # magnitudine dell'esplosione di ogni fetta della torta
lab1 = ['A','B','C','D']
plt.pie(x, colors = col1, labels = lab1, explode = ex1) # con esplosione (separazione)
# Out:
# ([<matplotlib.patches.Wedge at 0x19c6a4dcb90>,
# ...
#  [Text(1.346005620031349, 0.8650253584976707, 'A'),
#   Text(-0.3990885090653131, 1.0250504192145993, 'B'),
#   Text(-0.8899184718302892, -0.6465640830538323, 'C'),
#   Text(0.8104152212520455, -0.7437924234374792, 'D')])

# %%
# scatterplot

# %%
plt.scatter(x, y)

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(x, y) # bar plot orizzontale (h)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Vediamo ora alcuni plot **pandas** (per una trattazione più dettagliata vedi l'apposita sezione del notebook **A. Introduzione**).<br>
# Questa sezione riporta comunque alcuni plot pandas <u>ulteriori</u>.

# %%
import pandas as pd

# %%
import numpy as np

# %%
df1 = pd.DataFrame(np.random.rand(10, 4), columns = ['var1', 'var2', 'var3', 'var4'])

# %%
df1.head(10)
# Out:
#        var1      var2      var3      var4
# 0  0.517413  0.720849  0.767459  0.232513
# 1  0.026263  0.047557  0.290099  0.314636
# 2  0.192151  0.776297  0.093931  0.851647
# 3  0.483688  0.064331  0.766374  0.949794
# 4  0.965250  0.061828  0.217352  0.980889
# 5  0.395140  0.876946  0.218971  0.794599
# 6  0.070022  0.014435  0.798294  0.325322
# 7  0.687706  0.961088  0.463684  0.299119
# 8  0.568378  0.154768  0.987601  0.349298
# 9  0.654021  0.512722  0.322585  0.601885

# %%
df1.plot(kind = "bar")
# Out:
# <Axes: >

# %%
df1.plot(kind = "bar", stacked = True)
# Out:
# <Axes: >

# %%
df1.hist()
# Out:
# array([[<Axes: title={'center': 'var1'}>,
#         <Axes: title={'center': 'var2'}>],
#        [<Axes: title={'center': 'var3'}>,
#         <Axes: title={'center': 'var4'}>]], dtype=object)

# %%
df1['var1'].hist() # separatamente
# Out:
# <Axes: >

# %%
df1.loc[1]
# Out:
# var1    0.026263
# var2    0.047557
# var3    0.290099
# var4    0.314636
# Name: 1, dtype: float64

# %%
df1.loc[1].hist() # per riga
                  # le frequenze dei valori delle 4 colonne
# Out:
# <Axes: >

# %%
df1.boxplot(return_type = "axes")
# Out:
# <Axes: >

# %%
df1.plot(kind = "area")  # lineplot stacked (impilato)

                         # atteenzione: nei plot impilati conta il differenziale, non il valore assoluto
# Out:
# <Axes: >

# %%
df1.plot(kind = "area", color = col1)
# Out:
# <Axes: >

# %%
df1.plot(kind = "area", stacked = False)  # la scala dei valori è cambiata
# Out:
# <Axes: >

# %%
df1.plot(kind = "scatter", x = "var1", y = "var2")
# Out:
# <Axes: xlabel='var1', ylabel='var2'>

# %%
df1.plot(kind = "scatter", x = "var1", y = "var2")
# Out:
# <Axes: xlabel='var1', ylabel='var2'>

# %% [markdown]
# Per salvare un plot:

# %%
df1.plot(kind = "scatter", x = "var1", y = "var2")
plt.savefig('graph1.png', dpi = 600) # salva il plot su file; si specifica: nome file, formato e dpi
                                     # potendo scegliere, il formato png è il migliore in Jupyter

# %%
# %pwd
# Out:
# 'C:\\Users\\Utente\\Desktop\\salvataggi\\SALVATAGGIO DATI\\Documents\\Seminari\\Data Science (corsi)\\Corso ML con Python (Overnet - Aresys)'

# %%
plt.scatter(x, y) # l'altra forma di scatter plot vista prima (su x e y separatamente)

# %%
# stili per modificare un grafico

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# come applichiamo uno stile?

# %%
plt.style.use('dark_background')
df1.plot(kind = "area")
# Out:
# <Axes: >

# %%
plt.style.use('classic')
df1.plot(kind = "area")
# Out:
# <Axes: >

# %%
plt.style.use('seaborn-darkgrid')
df1.plot(kind = "area")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\anaconda3\envs\myenv\Lib\site-packages\matplotlib\style\core.py:129, in use(style)
#     128 try:
# --> 129     style = _rc_params_in_file(style)
#     130 except OSError as err:
#
# File ~\anaconda3\envs\myenv\Lib\site-packages\matplotlib\__init__.py:903, in _rc_params_in_file(fname, transform, fail_on_error)
#     902 rc_temp = {}
# --> 903 with _open_file_or_url(fname) as fd:
#     904     try:
#
# File ~\anaconda3\envs\myenv\Lib\contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#
# File ~\anaconda3\envs\myenv\Lib\site-packages\matplotlib\__init__.py:880, in _open_file_or_url(fname)
#     879 fname = os.path.expanduser(fname)
# --> 880 with open(fname, encoding='utf-8') as f:
#     881     yield f
#
# ...

# %% [markdown]
# Correzione del codice dell'assistente AI di Anaconda:

# %%
# Option 1: Use the updated style name
plt.style.use('dark_background')  # or another available style

# Option 2: If you want to see available styles, uncomment the line below
# print(plt.style.available)

# Option 3: If you have seaborn installed, use it directly
# import seaborn as sns
# sns.set_style("darkgrid")

df1.plot(kind="area")
# Out:
# <Axes: >

# %%
plt.style.use('ggplot')
df1.plot(kind = "area")
# Out:
# <Axes: >

# %%
# creiamo due oggetti casuali con numpy e li rappresentiamo graficamente

# %%
s1 = np.random.randn(100)               # array numpy

# %%
s2 = pd.Series(np.random.randn(100))    # serie pandas

# %%
plt.hist(s1) # non confondere con 'df1.hist' visto prima (4 istogrammi separati, uno per ogni variabile del df)
# Out:
# (array([ 2.,  5.,  8., 18., 28., 20., 13.,  4.,  1.,  1.]),
#  array([-2.88151432, -2.21673387, -1.55195342, -0.88717296, -0.22239251,
#          0.44238795,  1.1071684 ,  1.77194886,  2.43672931,  3.10150976,
#          3.76629022]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(s2)
# Out:
# (array([ 1.,  0., 10.,  8., 15., 12., 18., 18., 11.,  7.]),
#  array([-2.61085429, -2.16136134, -1.7118684 , -1.26237545, -0.81288251,
#         -0.36338957,  0.08610338,  0.53559632,  0.98508927,  1.43458221,
#          1.88407516]),
#  <BarContainer object of 10 artists>)

# %%
# adesso mettiamo a confronto i due dataset in uno stesso grafico (2 istogrammi sovrapposti!)

# %%
plt.hist(s1, color = "red", alpha = 0.3, bins = 15)
plt.hist(s2, color = "blue", alpha = 0.4, bins = 15)

                                                 # --> 3 colori: due per distinguere le due serie, il terzo per la parte di
                                                 #     serie nascosta
# Out:
# (array([ 1.,  0.,  0.,  6.,  6.,  6., 12.,  6.,  9., 13.,  9., 14.,  8.,
#          9.,  1.]),
#  array([-2.61085429, -2.31119232, -2.01153036, -1.7118684 , -1.41220644,
#         -1.11254447, -0.81288251, -0.51322055, -0.21355858,  0.08610338,
#          0.38576534,  0.6854273 ,  0.98508927,  1.28475123,  1.58441319,
#          1.88407516]),
#  <BarContainer object of 15 artists>)

# %% [markdown]
# # 7 Matplotlib Tricks to Better Visualize Your Machine Learning Models
# Vedi [qui](https://machinelearningmastery.com/7-matplotlib-tricks-to-better-visualize-your-machine-learning-models/).

# %% [markdown]
# # Varie

# %%
from IPython.display import IFrame
IFrame("matplotlib_syed_afroz.pdf", width=1000, height=600)
# Out:
#         <iframe
#             width="1000"
#             height="600"
#             src="matplotlib_syed_afroz.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# [GIF animate in *matplotlib*](https://www.linkedin.com/posts/davide-nardini_gif-matplotlib-plot-activity-7125753449505263616-RMkw?utm_source=share&utm_medium=member_desktop)

# %% [markdown]
# [utile post so](https://stackoverflow.com/questions/55396416/plotting-multiple-overlapped-histogram-with-pandas)

# %% [markdown]
# [Questo](https://stackoverflow.com/questions/14261903/how-can-i-open-the-interactive-matplotlib-window-in-ipython-notebook) utile plot parla di come ottenere grafici matplotlib interattivi in Jupyter.

# %% [markdown]
# Post linkedin su **Mosaic**:
# ![](mosaic_subplots.png)

# %% [markdown]
# **Annotazioni** (da [qui](https://blog.dailydoseofds.com/p/enrich-matplotlib-plots-with-annotations?utm_source=substack&publication_id=1119889&post_id=143555125&utm_medium=email&utm_content=share&utm_campaign=email-share&triggerShare=true&isFreemail=true&r=3hg5ec&triedRedirect=true))
# ![](matplotlib_with_annotations.png)
